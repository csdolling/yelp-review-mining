# %%
import pandas as pd

# %%
import json

# %%
business_json = pd.read_json("yelp_academic_dataset_business.json", lines=True)

# %%
business_json.head(10)
# Out:
#                            address  \
# 0                1314 44 Avenue NE
# 1
# 2              1335 rue Beaubien E
# 3                  211 W Monroe St
# 4              2005 Alyth Place SE
# 5  20235 N Cave Creek Rd, Ste 1115
# 6                   631 Bloor St W
# 7      3417 Derry Road E, Unit 103
# 8               1440 N. Dysart Ave
# 9                  209 Oakland Ave
#
#                                           attributes             business_id  \
# 0  {'BikeParking': 'False', 'BusinessAcceptsCredi...  Apn5Q_b6Nz61Tq4XzPdf9A
# 1  {'Alcohol': 'none', 'BikeParking': 'False', 'B...  AjEbIBw6ZFfln7ePHha9PA
# 2  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  O8S5hYJ1SMc8fA4QBtVujA
# 3                                               None  bFzdJJ3wp3PZssNEsyU23g
# 4             {'BusinessAcceptsCreditCards': 'True'}  8USyCYqpScwiNEb58Bt6CA
# 5  {'BikeParking': 'True', 'BusinessAcceptsCredit...  45bWSZtniwPRiqlivpS8Og
# ...

# %%
business_json.columns
# Out:
# Index(['address', 'attributes', 'business_id', 'categories', 'city', 'hours',
#        'is_open', 'latitude', 'longitude', 'name', 'neighborhood',
#        'postal_code', 'review_count', 'stars', 'state'],
#       dtype='object')

# %%
business_json.shape
# Out:
# (188593, 15)

# %%
[rows,columns] = business_json.shape

# %%
business_json.describe()
# Out:
#              is_open       latitude      longitude   review_count  \
# count  188593.000000  188587.000000  188587.000000  188593.000000
# mean        0.830391      38.506793     -97.490873      31.797310
# std         0.375290       5.122684      17.693360     104.124212
# min         0.000000     -71.753941    -180.000000       3.000000
# 25%         1.000000      33.630878    -112.279276       4.000000
# 50%         1.000000      36.143595    -111.777460       9.000000
# 75%         1.000000      43.593106     -79.982958      24.000000
# max         1.000000      85.051129     115.086769    7968.000000
#
#                stars
# count  188593.000000
# mean        3.631550
# std         1.016783
# min         1.000000
# 25%         3.000000
# 50%         3.500000
# 75%         4.500000
# max         5.000000

# %%
print(business_json.loc[0]['is_open'])
# Out:
# 1

# %%
print(business_json.loc[0]['state'])
# Out:
# AB

# %%
print(business_json.loc[100]['state'])
# Out:
# AZ

# %%
is_AZ = business_json['state']=="AZ"

# %%
print(is_AZ.head())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: state, dtype: bool

# %%
business_json_AZ = business_json[is_AZ]

# %%
print(business_json_AZ.shape)
# Out:
# (56495, 15)

# %%
print(business_json_AZ.head())
# Out:
#                             address  \
# 3                   211 W Monroe St
# 5   20235 N Cave Creek Rd, Ste 1115
# 8                1440 N. Dysart Ave
# 12                  2801 N 15th Ave
# 22                  4131 N 83rd Ave
#
#                                            attributes             business_id  \
# 3                                                None  bFzdJJ3wp3PZssNEsyU23g
# 5   {'BikeParking': 'True', 'BusinessAcceptsCredit...  45bWSZtniwPRiqlivpS8Og
# 8   {'Alcohol': 'none', 'Ambience': '{'romantic': ...  8-NRKkPY1UiFXW20WXKiXg
# 12  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...  _c3ixq9jYKxhLUB0czi0ug
# 22  {'Ambience': '{'romantic': False, 'intimate': ...  3ByGQOVgds2YEu6kzl-XEQ
#
#                                            categories      city  \
# 3                       Insurance, Financial Services   Phoenix
# 5                                  Coffee & Tea, Food   Phoenix
# 8                                Mexican, Restaurants  Avondale
# ...

# %%
over_100 = business_json_AZ['review_count']>=100

# %%
print(over_100.head())
# Out:
# 3     False
# 5     False
# 8     False
# 12     True
# 22    False
# Name: review_count, dtype: bool

# %%
AZ_over_100 = business_json_AZ[over_100]

# %%
print(AZ_over_100.shape)
# Out:
# (4180, 15)

# %%
print(AZ_over_100.head())
# Out:
#                            address  \
# 12                 2801 N 15th Ave
# 47                  1111 W Bell Rd
# 108           6316 N Scottsdale Rd
# 140  6751 N Sunset Blvd, Ste E-110
# 177       16705 E Williamsfield Rd
#
#                                             attributes  \
# 12   {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 47   {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 108  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 140  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 177  {'Alcohol': 'none', 'Ambience': '{'romantic': ...
#
#                 business_id  \
# 12   _c3ixq9jYKxhLUB0czi0ug
# 47   cKRMmytHxaSt8F0SMEzKqg
# 108  F73T-N5lRNL2Gcpg0Q4KKw
# 140  s2gjJKptpkmwSXYRtfptZQ
# 177  maBe6J_QSeYlAa1YNkAyVA
#
#                                             categories        city  \
# 12   Bars, Sports Bars, Dive Bars, Burgers, Nightli...     Phoenix
# 47   Event Planning & Services, Soup, Salad, Mexica...     Phoenix
# ...

# %%
is_Mexican = AZ_over_100['categories'].str.contains('Mexican', na=False)
AZ_Mexican = AZ_over_100[is_Mexican]
print(AZ_Mexican.shape)
AZ_Mexican.head(5)
# Out:
# (440, 15)
#                                 address  \
# 47                       1111 W Bell Rd
# 302             1301 W Grand Ave, Ste 1
# 3261  1490 E Williams Field Rd, Ste 101
# 3599               1560 N Litchfield Rd
# 4070                      1009 S 7th St
#
#                                              attributes  \
# 47    {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 302   {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 3261  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 3599  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 4070  {'Alcohol': 'none', 'Ambience': '{'romantic': ...
#
#                  business_id  \
# 47    cKRMmytHxaSt8F0SMEzKqg
# 302   sh69ApUyPhAltAMpv5vX3w
# 3261  bQ2uuNkOxgUQRM7Y7RJDXQ
# 3599  lXYTzkRVMHPYGcDRc_8JvQ
# 4070  CFyPbqZaxoBTjOmVjSn_8Q
#
#                                              categories      city  \
# 47    Event Planning & Services, Soup, Salad, Mexica...   Phoenix
# ...

# %%
is_American = AZ_over_100['categories'].str.contains('American', na=False)
AZ_American = AZ_over_100[is_American]
print(AZ_American.shape)
AZ_American.head(5)
# Out:
# (995, 15)
#                            address  \
# 140  6751 N Sunset Blvd, Ste E-110
# 731              3877 S Gilbert Rd
# 744           6113 N Scottsdale Rd
# 923           502 E Thunderbird Rd
# 955       20751 N Pima Rd, Ste 120
#
#                                             attributes  \
# 140  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 731  {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# 744  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 923  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 955  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
#
#                 business_id  \
# 140  s2gjJKptpkmwSXYRtfptZQ
# 731  HpxtJa8EQOZRpuLToLseew
# 744  zrDi4gEaUi64lAMfJU51dw
# 923  bVqNtwcwIz2gAacHWYF2lw
# 955  a6nZdebWiAZ97jync-vnGA
#
#                                             categories        city  \
# 140  Karaoke, Country Dance Halls, Bars, Nightlife,...    Glendale
# 731  Restaurants, Sandwiches, Salad, Soup, American...     Gilbert
# ...

# %%
is_Italian = AZ_over_100['categories'].str.contains('Italian', na=False)
AZ_Italian = AZ_over_100[is_Italian]
print(AZ_Italian.shape)
AZ_Italian.head(5)
# Out:
# (342, 15)
#                                 address  \
# 108                6316 N Scottsdale Rd
# 426                2580 W Chandler Blvd
# 1451       6606 E Mckellips Rd, Ste 104
# 2718        13291 W McDowell Rd, Ste E7
# 2763  1524 E Williams Field Rd, Ste 101
#
#                                              attributes  \
# 108   {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 426   {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 1451  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 2718  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 2763  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
#
#                  business_id  \
# 108   F73T-N5lRNL2Gcpg0Q4KKw
# 426   UGyEr_PMA-v1cuim0gMPlQ
# 1451  Kz4WS00PcqOJgxfZawk4dQ
# 2718  r4HkiC71nB9k8Fe8zIORFQ
# 2763  FmraE2CWt65VRnEqCAqNEg
#
#                                              categories        city  \
# 108   Food, Restaurants, Italian, Bars, Wine Bars, D...  Scottsdale
# ...

# %%
is_Japanese = AZ_over_100['categories'].str.contains('Japanese', na=False)
AZ_Japanese = AZ_over_100[is_Japanese]
print(AZ_Japanese.shape)
AZ_Japanese.head(5)
# Out:
# (172, 15)
#                          address  \
# 1097            14144 N 100th St
# 4688   114 W Adams St, Ste C-103
# 5229                 21 E 6th St
# 8722            4320 N Miller Rd
# 11252          4214 W Dunlap Ave
#
#                                               attributes  \
# 1097   {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 4688   {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 5229   {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 8722   {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 11252  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
#
#                   business_id  \
# 1097   tQm5R5UsWBzxsOGLPjfLJQ
# 4688   L6ZPG8lO1tMGmHimSjuEMg
# 5229   9kjk05G50XWnmJQBz_wcnw
# 8722   scj1FBV05NVe0iQxplNNYw
# 11252  25c15dEPrBrWr4tR1r6sTg
#
#                                              categories        city  \
# 1097         Japanese, Sushi Bars, Restaurants, Seafood  Scottsdale
# 4688     Ramen, Italian, Noodles, Japanese, Restaurants     Phoenix
# ...

# %%
is_Chinese = AZ_over_100['categories'].str.contains('Chinese', na=False)
AZ_Chinese = AZ_over_100[is_Chinese]
print(AZ_Chinese.shape)
AZ_Chinese.head(5)
# Out:
# (191, 15)
#                              address  \
# 677                  13825 N 32nd St
# 1585         740 S Mill Ave, Ste 140
# 5392           3021 N Alma School Rd
# 7335               832 W Baseline Rd
# 7864  814 E Union Hills Dr, Ste C-14
#
#                                              attributes  \
# 677   {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 1585  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 5392  {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# 7335  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 7864  {'Alcohol': 'none', 'Ambience': '{'romantic': ...
#
#                  business_id                                       categories  \
# 677   fnaDx7UD4MiodQlgYHDwsQ                             Restaurants, Chinese
# 1585  6W20fKnjqPTSU2irnSVmSQ  Restaurants, Chinese, Asian Fusion, Gluten-Free
# 5392  lcSsIw_oC-OT2veksCtRwg                             Chinese, Restaurants
# ...

# %%
is_Mediterranean = AZ_over_100['categories'].str.contains('Mediterranean', na=False)
AZ_Mediterranean = AZ_over_100[is_Mediterranean]
print(AZ_Mediterranean.shape)
AZ_Mediterranean.head(5)
# Out:
# (139, 15)
#                            address  \
# 1162             521 W Mcdowell Rd
# 2305      4312 W Cactus Rd, Ste 10
# 6613   227 E Baseline Rd, Ste J007
# 10209              3332 S Mill Ave
# 11213               525 S Mill Ave
#
#                                               attributes  \
# 1162   {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# 2305   {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# 6613   {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 10209  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 11213  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
#
#                   business_id  \
# 1162   e880MGw6C6PJL-n3EJoY_g
# 2305   3RHgRaCRPuLdJ6PLZL6MGA
# 6613   gMN6VKmu4E1EmlMYzz9A3w
# 10209  eN8mkjt_q686hGKi-A9ceg
# 11213  JwyH48vqADWY6HieOMDxgQ
#
#                                               categories      city  \
# 1162   Steakhouses, Southern, Greek, Sandwiches, Rest...   Phoenix
# ...

# %%
is_Thai = AZ_over_100['categories'].str.contains('Thai', na=False)
AZ_Thai = AZ_over_100[is_Thai]
print(AZ_Thai.shape)
AZ_Thai.head(5)
# Out:
# (112, 15)
#                            address  \
# 785                 3510 E Bell Rd
# 5881  4995 S Alma School Rd, Ste 1
# 6585       114 W Adams St, Ste 104
# 6717          2040 W Chandler Blvd
# 8993       7350 W Bell Rd, Ste 201
#
#                                              attributes  \
# 785   {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# 5881  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 6585  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 6717  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 8993  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
#
#                  business_id  \
# 785   fXzMs__3HjTYwKPMAb4jYA
# 5881  dUOueknc1hk6m78AaiIwuQ
# 6585  4vkOZ0kW4Hor43XqqNc0Og
# 6717  eOl6WS3oAjtGZpcXfv8tlA
# 8993  GhWMl0J2gOOH61BhBMTAAA
#
#                                              categories      city  \
# 785                                   Thai, Restaurants   Phoenix
# 5881  Gluten-Free, Thai, Vegan, Restaurants, Asian F...  Chandler
# ...

# %%
AZ_Thai.to_json(r"C:\Users\Carmen\Downloads\Thai.JSON")

# %%
AZ_Thai.to_csv('Thai.csv')

# %%
AZ_Mexican.to_json(r"C:\Users\Carmen\Downloads\Mexican.JSON")
AZ_Mexican.to_csv('Mexican.csv')

# %%
AZ_American.to_json(r"C:\Users\Carmen\Downloads\American.JSON")
AZ_American.to_csv('American.csv')

# %%
AZ_Italian.to_json(r"C:\Users\Carmen\Downloads\Italian.JSON")
AZ_Italian.to_csv('Italian.csv')

# %%
AZ_Japanese.to_json(r"C:\Users\Carmen\Downloads\Japanese.JSON")
AZ_Japanese.to_csv('Japanese.csv')

# %%
AZ_Chinese.to_json(r"C:\Users\Carmen\Downloads\Chinese.JSON")
AZ_Chinese.to_csv('Chinese.csv')

# %%
AZ_Mediterranean.to_json(r"C:\Users\Carmen\Downloads\Mediterranean.JSON")
AZ_Mediterranean.to_csv('Mediterranean.csv')
